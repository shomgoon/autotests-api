# %%
import time
import random


def get_random_email() -> str:
    return f'test_{time.time()}@email.com'


# 1. Генерация случайных данных
def get_random_data() -> str:
    return {
        "first_name": f"User{random.randint(1, 1000)}",
        "last_name": f"Test{random.randint(1, 1000)}",
        "email": f"test{int(time.time())}@example.com"  # Уникальный email
    }

print(get_random_email())
print(get_random_data()["first_name"])
# Out:
# test_1765616318.0044086@email.com
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      11     return {
#      12         "first_name": f"User{random.randint(1, 1000)}",
#      13         "last_name": f"Test{random.randint(1, 1000)}",
#      14         "email": f"test{int(time.time())}@example.com"  # Уникальный email
#      15     }
#      17 print(get_random_email())
# ---> 18 print(get_random_data('first_name'))
#
# TypeError: get_random_data() takes 0 positional arguments but 1 was given
